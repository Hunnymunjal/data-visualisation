# %% [raw]
#                                     19csu130 & 19csu134
#                                        POLICEDATASET
#                                        PROJECT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
data = pd.read_csv("3. Police Data.csv")
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
data.tail()
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 65530        25.0       White                        Speeding   Speeding
# 65531        58.0       White                        Speeding   Speeding
# 65532        27.0       Black  Equipment/Inspection Violation  Equipment
# 65533         NaN         NaN                             NaN        NaN
# 65534        27.0       White                        Speeding   Speeding
#
#        search_conducted search_type stop_outcome is_arrested stop_duration  \
# ...

# %%
data.head()
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
data.driver_gender.unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
data.driver_gender.value_counts()
# Out:
# M    45164
# F    16310
# Name: driver_gender, dtype: int64

# %%
data.isnull()
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   driver_gender       61474 non-null  object
#  3   driver_age_raw      61481 non-null  float64
#  4   driver_age          61228 non-null  float64
#  5   driver_race         61475 non-null  object
#  6   violation_raw       61475 non-null  object
#  7   violation           61475 non-null  object
#  8   search_conducted    65535 non-null  bool
#  9   search_type         2479 non-null   object
#  10  stop_outcome        61475 non-null  object
#  11  is_arrested         61475 non-null  object
#  12  stop_duration       61475 non-null  object
#  13  drugs_related_stop  65535 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 6.1+ MB

# %%
len(data)
# Out:
# 65535

# %%
df=data.copy(deep=False)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
df=data.dropna()

# %%
df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# dtype: int64

# %%
df
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24      8/28/2005      1:00             M          1979.0        26.0
# 40      10/1/2005      0:00             M          1988.0        17.0
# 41      10/1/2005      0:00             M          1988.0        17.0
# 80      10/2/2005      9:30             M          1975.0        30.0
# 106     10/3/2005     14:00             M          1978.0        27.0
# ...           ...       ...           ...             ...         ...
# 65254  11/25/2012      0:33             M          1984.0        28.0
# 65358  11/29/2012      1:06             M          1986.0        26.0
# 65408  11/30/2012     22:37             F          1986.0        26.0
# 65409  11/30/2012     23:40             M          1980.0        32.0
# 65499   12/5/2012     23:13             M          1985.0        27.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
df.shape
# Out:
# (2477, 14)

# %%
df.describe()
# Out:
#        driver_age_raw   driver_age
# count     2477.000000  2477.000000
# mean      1978.096084    30.544207
# std         10.590428    10.414790
# min       1930.000000    15.000000
# 25%       1971.000000    22.000000
# 50%       1981.000000    27.000000
# 75%       1986.000000    37.000000
# max       1994.000000    79.000000

# %%
len(df)
# Out:
# 2477

# %%
data[data.is_arrested == False]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 41      10/1/2005      0:00             M          1988.0        17.0
# 106     10/3/2005     14:00             M          1978.0        27.0
# 163     10/5/2005     22:50             M          1980.0        25.0
# 315    10/11/2005     13:40             M          1963.0        42.0
# 377    10/16/2005      0:00             M          1981.0        24.0
# ...           ...       ...           ...             ...         ...
# 65241  11/24/2012     14:13             M          1979.0        33.0
# 65358  11/29/2012      1:06             M          1986.0        26.0
# 65408  11/30/2012     22:37             F          1986.0        26.0
# 65409  11/30/2012     23:40             M          1980.0        32.0
# 65499   12/5/2012     23:13             M          1985.0        27.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data[data.is_arrested == True]
# Out:
#         stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 3       2/20/2005     17:15           NaN             M          1986.0
# 22       8/8/2005      2:09           NaN             M          1955.0
# 24      8/28/2005      1:00           NaN             M          1979.0
# 31      9/28/2005      6:20           NaN             M          1982.0
# 40      10/1/2005      0:00           NaN             M          1988.0
# ...           ...       ...           ...           ...             ...
# 65316  11/26/2012     17:59           NaN             M          1983.0
# 65330  11/27/2012     10:42           NaN             M          1977.0
# 65344  11/28/2012     10:00           NaN             M          1985.0
# 65367  11/29/2012     10:59           NaN             M          1968.0
# 65395  11/30/2012     19:44           NaN             M          1974.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
len(data[data.is_arrested == True])
# Out:
# 968

# %%
df.sort_values(by="driver_age" , ascending = False)
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 32835   2/25/2009     15:41             M          1930.0        79.0
# 29355   10/2/2008     20:42             M          1932.0        76.0
# 23711    2/9/2008      1:42             M          1938.0        70.0
# 40096    2/2/2010     11:37             M          1940.0        70.0
# 27141    7/4/2008     22:47             M          1938.0        70.0
# ...           ...       ...           ...             ...         ...
# 30780  11/29/2008     23:56             M          1991.0        17.0
# 45438  10/10/2010     20:10             M          1994.0        16.0
# 21981   12/1/2007      0:01             M          1991.0        16.0
# 26069   5/25/2008      1:06             F          1992.0        16.0
# 25294   4/21/2008     11:19             M          1993.0        15.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
df.sort_values("driver_age")
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 25294   4/21/2008     11:19             M          1993.0        15.0
# 26069   5/25/2008      1:06             F          1992.0        16.0
# 45438  10/10/2010     20:10             M          1994.0        16.0
# 21981   12/1/2007      0:01             M          1991.0        16.0
# 46315  11/27/2010      0:56             M          1993.0        17.0
# ...           ...       ...           ...             ...         ...
# 40096    2/2/2010     11:37             M          1940.0        70.0
# 23711    2/9/2008      1:42             M          1938.0        70.0
# 27141    7/4/2008     22:47             M          1938.0        70.0
# 29355   10/2/2008     20:42             M          1932.0        76.0
# 32835   2/25/2009     15:41             M          1930.0        79.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
data[data.violation == "Speeding"].driver_gender.value_counts()
# Out:
# M    693
# F    102
# Name: driver_gender, dtype: int64

# %%
# does gender affect who gets searched during a stop

# %%
data.head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24   8/28/2005      1:00             M          1979.0        26.0
# 40   10/1/2005      0:00             M          1988.0        17.0
# 41   10/1/2005      0:00             M          1988.0        17.0
# 80   10/2/2005      9:30             M          1975.0        30.0
# 106  10/3/2005     14:00             M          1978.0        27.0
#
#     driver_race                   violation_raw         violation  \
# 24        White         Other Traffic Violation  Moving violation
# 40        White  Equipment/Inspection Violation         Equipment
# 41        White  Equipment/Inspection Violation         Equipment
# 80        White                        Speeding          Speeding
# 106       Black  Equipment/Inspection Violation         Equipment
#
#      search_conducted                          search_type   stop_outcome  \
# 24               True  Incident to Arrest,Protective Frisk  Arrest Driver
# ...

# %%
data.groupby("driver_gender").search_conducted.sum()
# Out:
# driver_gender
# F     366.0
# M    2111.0
# Name: search_conducted, dtype: float64

# %%
# compare the age distributions for each violation

# %%
data.groupby('violation').driver_age.describe()
# Out:
#                      count       mean        std   min   25%   50%   75%   max
# violation
# Equipment            539.0  29.254174   9.568786  16.0  22.0  26.0  34.0  70.0
# Moving violation     690.0  32.221739  11.302226  15.0  23.0  29.0  40.0  79.0
# Other                164.0  33.073171  11.775279  17.0  23.0  30.0  42.0  65.0
# Registration/plates  289.0  31.387543  10.667415  16.0  23.0  29.0  37.0  65.0
# Speeding             795.0  29.134591   9.405944  17.0  22.0  26.0  33.0  68.0

# %%
data.describe(include= "all")
# Out:
#        stop_date stop_time driver_gender  driver_age_raw   driver_age  \
# count       2477      2477          2477     2477.000000  2477.000000
# unique      1551       969             2             NaN          NaN
# top     3/5/2009      0:00             M             NaN          NaN
# freq           7        15          2111             NaN          NaN
# mean         NaN       NaN           NaN     1978.096084    30.544207
# std          NaN       NaN           NaN       10.590428    10.414790
# min          NaN       NaN           NaN     1930.000000    15.000000
# 25%          NaN       NaN           NaN     1971.000000    22.000000
# 50%          NaN       NaN           NaN     1981.000000    27.000000
# 75%          NaN       NaN           NaN     1986.000000    37.000000
# max          NaN       NaN           NaN     1994.000000    79.000000
#
#        driver_race violation_raw violation search_conducted  \
# count         2477          2477      2477             2477
# ...

# %%
data_df=data[data["search_type"].str.contains("Arrest")]
data_df
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24      8/28/2005      1:00             M          1979.0        26.0
# 80      10/2/2005      9:30             M          1975.0        30.0
# 118     10/4/2005      1:20             M          1956.0        49.0
# 163     10/5/2005     22:50             M          1980.0        25.0
# 208     10/7/2005     12:00             M          1947.0        58.0
# ...           ...       ...           ...             ...         ...
# 64948  11/12/2012      8:41             M          1977.0        35.0
# 65090  11/19/2012      1:06             M          1989.0        23.0
# 65120  11/20/2012      1:10             M          1981.0        31.0
# 65186  11/21/2012     20:46             M          1969.0        43.0
# 65219  11/23/2012     20:03             M          1979.0        33.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
len(data["search_type"].str.contains("Arrest"))
# Out:
# 2477

# %%
plt.figure(figsize=(10,7))
sns.distplot(data['driver_age_raw']);

# %%
data.corr()
# Out:
#                     driver_age_raw  driver_age  search_conducted  \
# driver_age_raw            1.000000   -0.978952               NaN
# driver_age               -0.978952    1.000000               NaN
# search_conducted               NaN         NaN               NaN
# drugs_related_stop        0.147028   -0.124785               NaN
#
#                     drugs_related_stop
# driver_age_raw                0.147028
# driver_age                   -0.124785
# search_conducted                   NaN
# drugs_related_stop            1.000000

# %%
sns.heatmap(data.corr() , cmap='Blues');
